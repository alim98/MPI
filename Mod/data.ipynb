# %%
from Dataloader import parse_args, load_volumes, VideoMAEDataset, SimpleVideoProcessor

# %% [markdown]
# # Doesnt show pre and post synapse

# %%
# %load_ext autoreload
# %autoreload 2
import Dataloader
from Dataloader import parse_args, main
# import dataloader
# %autoreload 2

# %%
# Define the arguments
class Args:
    raw_base_dir = "7_bboxes_plus_seg/raw"
    seg_base_dir = "7_bboxes_plus_seg/raw"
    add_mask_base_dir = "vesicle_cloud__syn_interface__mitochondria_annotation"
    excel_file = ""
    bbox_name = ["bbox1"]
    batch_size = 2
    num_epochs = 5
    learning_rate = 1e-4
    weight_decay = 1e-2
    subvol_size = 80
    num_frames = 80
    segmentation_type = 5
    alpha = 0.3
    size=(80,80)
# Create an instance of Args
args = Args()

# Run the main function and store the results
cubes, synapse_info = main(args)
# Out:
# bbox1
# Processed 58 cubes successfully.

# %%
synapse_info.head(100)
# Out:
#                       Var1  central_coord_1  central_coord_2  central_coord_3  \
# 0   non_spine_synapsed_056              171              260              350
# 1    non_spine_synapse_057              223              113              425
# 2    non_spine_synapse_058              280              102              377
# 3    non_spine_synapse_063              455              131              162
# 4    non_spine_synapse_062              138              121              302
# 5    non_spine_synapse_061              122              113              325
# 6    non_spine_synapse_060              175              257              297
# 7    non_spine_synapse_059              300              383              404
# 8    non_spine_synapse_054              274              158              188
# 9    non_spine_synapse_053              467              348              242
# 10   non_spine_synapse_052              467              390              244
# 11   non_spine_synapse_051              441              362              255
# 12   non_spine_synapse_050              340              188              269
# 13   non_spine_synapse_049              344              376              359
# 14   non_spine_synapse_048              357              329              309
# 15   non_spine_synapse_047              467              425              318
# 16   non_spine_synapse_046              138              307              185
# 17   non_spine_synapse_045              235              303              300
# 18   non_spine_synapse_044              248              286              293
# 19   non_spine_synapse_040              113              253              403
# 20   non_spine_synapse_038              165              367              392
# 21   non_spine_synapse_037              156              287              360
# 22   non_spine_synapse_036              130              247              389
# 23   non_spine_synapse_035              252              360              356
# 24   non_spine_synapse_034              453              386              324
# 25   non_spine_synapse_033              396              105              261
# 26   non_spine_synapse_032              394              284              259
# 27   non_spine_synapse_031              397              318              361
# 28   non_spine_synapse_030              247              225              192
# 29   non_spine_synapse_029              412              338              290
# 30   non_spine_synapse_028              440              288              256
# 31   non_spine_synapse_027              169              336              146
# 32   non_spine_synapse_026              252              377              268
# 33   non_spine_synapse_025              468              424              292
# 34   non_spine_synapse_024              460              396              339
# 35   non_spine_synapse_023              459              414              350
# 36   non_spine_synapse_022              198              300              322
# 37   non_spine_synapse_021              155              353              165
# 38   non_spine_synapse_020              150              366              158
# 39   non_spine_synapse_019              156              330              163
# 40   non_spine_synapse_018              132              293              179
# 41   non_spine_synapse_017              181              373              180
# 42   non_spine_synapse_016              161              353              195
# 43   non_spine_synapse_015              195              409              195
# 44   non_spine_synapse_014              211              437              195
# 45   non_spine_synapse_013              189              241              235
# 46   non_spine_synapse_012              418              219              199
# 47   non_spine_synapse_011              352              337              341
# 48  non_spine_synapsed_010              203              347              359
# 49   non_spine_synapse_009              264              444              469
# 50   non_spine_synapse_008              177              266              345
# 51   non_spine_synapse_007              269              466              454
# 52   non_spine_synapse_006              169              322              354
# 53   non_spine_synapse_005              367              354              369
# 54   non_spine_synapse_004              339              370              395
# 55   non_spine_synapse_003              278              385              395
# 56   non_spine_synapse_002              252              388              395
# 57   non_spine_synapse_001              253              343              337
#
#     side_1_coord_1  side_1_coord_2  side_1_coord_3  side_2_coord_1  \
# 0              171             268             359             171
# 1              223             112             438             223
# 2              280              94             400             280
# 3              455             134             181             455
# 4              135             113             298             140
# 5              117             113             316             127
# 6              175             272             294             175
# 7              300             391             394             300
# 8              274             158             209             274
# 9              467             346             233             467
# 10             467             385             233             467
# 11             441             360             242             441
# 12             340             189             244             340
# 13             344             381             350             344
# 14             355             339             309             356
# 15             453             425             318             477
# 16             133             307             178             143
# 17             235             306             295             235
# 18             248             289             285             248
# 19             121             254             403             105
# 20             167             367             402             163
# 21             169             293             360             142
# 22             140             255             389             122
# 23             247             351             356             252
# 24             440             386             325             465
# 25             410             105             263             387
# 26             391             292             259             401
# 27             384             318             374             405
# 28             247             216             200             247
# 29             417             338             278             410
# 30             451             288             243             434
# 31             154             337             146             178
# 32             257             389             268             240
# 33             458             423             292             478
# 34             450             396             340             467
# 35             449             414             347             470
# 36             202             300             330             193
# 37             145             347             165             162
# 38             144             358             158             154
# 39             143             328             163             163
# 40             125             301             179             138
# 41             181             352             180             180
# 42             177             342             195             149
# 43             171             406             195             207
# 44             220             443             201             199
# 45             189             224             235             189
# 46             408             211             199             425
# 47             352             331             354             352
# 48             216             338             359             188
# 49             261             452             469             265
# 50             189             273             345             164
# 51             260             464             454             276
# 52             185             316             354             157
# 53             367             343             371             367
# 54             333             359             395             344
# 55             274             374             395             280
# 56             253             374             395             253
# 57             256             328             337             253
#
#     side_2_coord_2  side_2_coord_3 bbox_name
# 0              260             340     bbox1
# 1              114             407     bbox1
# 2              108             364     bbox1
# 3              127             145     bbox1
# 4              127             312     bbox1
# 5              113             334     bbox1
# 6              238             301     bbox1
# 7              369             418     bbox1
# 8              155             171     bbox1
# 9              346             257     bbox1
# 10             392             263     bbox1
# 11             364             269     bbox1
# 12             189             284     bbox1
# 13             372             369     bbox1
# 14             317             309     bbox1
# 15             424             318     bbox1
# 16             307             190     bbox1
# 17             298             312     bbox1
# 18             283             305     bbox1
# 19             251             403     bbox1
# 20             367             383     bbox1
# 21             280             360     bbox1
# 22             241             389     bbox1
# 23             366             353     bbox1
# 24             386             321     bbox1
# 25             105             262     bbox1
# 26             264             259     bbox1
# 27             318             356     bbox1
# 28             246             175     bbox1
# 29             342             300     bbox1
# 30             288             271     bbox1
# 31             339             146     bbox1
# 32             368             268     bbox1
# 33             423             292     bbox1
# 34             396             340     bbox1
# 35             414             352     bbox1
# 36             300             313     bbox1
# 37             355             165     bbox1
# 38             374             158     bbox1
# 39             339             163     bbox1
# 40             284             179     bbox1
# 41             382             168     bbox1
# 42             362             195     bbox1
# 43             411             195     bbox1
# 44             442             195     bbox1
# 45             249             234     bbox1
# 46             226             199     bbox1
# 47             343             333     bbox1
# 48             354             359     bbox1
# 49             432             469     bbox1
# 50             259             345     bbox1
# 51             462             454     bbox1
# 52             329             354     bbox1
# 53             361             361     bbox1
# 54             381             395     bbox1
# 55             390             395     bbox1
# 56             396             395     bbox1
# 57             356             337     bbox1

# %%
import matplotlib.pyplot as plt

#
# Print the shape of the cubes
print(f"Cubes shape: {len(cubes)} cubes, each with shape {cubes[0].shape}")
# Out:
# Cubes shape: 58 cubes, each with shape torch.Size([80, 3, 80, 80])

# %%
import matplotlib.pyplot as plt
import numpy as np
import imageio
from IPython.display import Image, display

# Select a cube (e.g., the first one)
cube = cubes[1]  # Shape: (num_frames, 3, H, W)

# Convert the cube to a numpy array and normalize it
cube_np = cube.numpy()  # Convert to numpy
cube_np = (cube_np - cube_np.min()) / (cube_np.max() - cube_np.min())  # Normalize to [0, 1]
cube_np = (cube_np * 255).astype(np.uint8)  # Scale to [0, 255]

# Rearrange the dimensions to (num_frames, H, W, 3)
cube_np = np.transpose(cube_np, (0, 2, 3, 1))

# Create a list of frames
frames = [cube_np[i] for i in range(cube_np.shape[0])]

# Save the frames as a GIF
gif_path = "cube.gif"
imageio.mimsave(gif_path, frames, format="GIF", fps=10)  # Save with 5 frames per second

# Display the GIF in the notebook
display(Image(filename=gif_path))
